# %%
import pandas as pd
import geopandas as gpd
import json
import geojson
import requests
import csv 
import pprint

pp = pprint.PrettyPrinter()

# %%
#San Francisco

# %%
# download Assessor Data
assessor_url = 'https://data.sfgov.org/resource/wv5m-vpq2.csv'
assessor = pd.read_csv(assessor_url)
assessor.head()
# Out:
#    closed_roll_year                     property_location parcel_number  \
# 0              2017  0000 2655 HYDE                ST0W30     0026T256A
# 1              2017  0455 0453 BUSH                ST0000       0287019
# 2              2017  0000 0165 JEFFERSON           ST0000      0013006A
# 3              2017  0000 2655 HYDE                ST0W03     0026T373A
# 4              2017  0000 2655 HYDE                ST0303     0026T216B
#
#    block   lot  volume_number use_code     use_definition property_class_code  \
# 0  0026T  256A              1     COMM    Commercial Misc                  TS
# 1   0287   019              3     COMR  Commercial Retail                   C
# 2   0013  006A              1     COMR  Commercial Retail                   C
# 3  0026T  373A              1     COMM    Commercial Misc                  TS
# 4  0026T  216B              1     COMM    Commercial Misc                  TS
#
# ...

# %%
assessor.describe()
# Out:
#           closed_roll_year        volume_number  year_property_built  \
# count             1,000.00             1,000.00                 0.00
# mean              2,017.00                 1.16                  nan
# std                   0.00                 1.29                  nan
# min               2,017.00                 1.00                  nan
# 25%               2,017.00                 1.00                  nan
# 50%               2,017.00                 1.00                  nan
# 75%               2,017.00                 1.00                  nan
# max               2,017.00                38.00                  nan
#
#        number_of_bathrooms   number_of_bedrooms      number_of_rooms  \
# count             1,000.00             1,000.00             1,000.00
# mean                  1.34                 0.21                 5.73
# std                  13.62                 0.97                44.39
# ...

# %%
# download Land Use Data 2016
land_use_url = 'https://data.sfgov.org/resource/a2rp-pwkh.csv'
land_use = pd.read_csv(land_use_url)
land_use.head()
# Out:
#    objectid   blklot                                           the_geom  \
# 0         1  0026013  MULTIPOLYGON (((-122.42108072666898 37.8047751...
# 1         2  0026014  MULTIPOLYGON (((-122.42117903244349 37.8047629...
# 2         3  0026015  MULTIPOLYGON (((-122.42126451502638 37.8047522...
# 3         4  0026016  MULTIPOLYGON (((-122.42134572244261 37.8047421...
# 4         5  0026017  MULTIPOLYGON (((-122.4215252467804 37.80471971...
#
#   mapblklot block_num lot_num  from_st  to_st street st_type     ...       \
# 0   0026013      0026     013    838.0  842.0    BAY      ST     ...
# 1   0026014      0026     014    844.0  844.0    BAY      ST     ...
# 2   0026015      0026     015    848.0  850.0    BAY      ST     ...
# 3   0026016      0026     016    860.0  862.0    BAY      ST     ...
# 4   0026017      0026     017    870.0  872.0    BAY      ST     ...
#
#    total_uses   landuse  cie  med  mips  retail  pdr  visitor  shape_leng  \
# ...

# %%
land_use.describe()
# Out:
#           objectid      from_st        to_st     resunits       bldgsqft  \
# count   1000.00000   982.000000   982.000000  1000.000000    1000.000000
# mean     511.85600   949.503055   957.960285     4.466000    6910.703000
# std      473.00254   809.774650   823.269482    13.654424   21511.275465
# min        1.00000     0.000000     0.000000     0.000000       0.000000
# 25%      250.75000   291.000000   294.250000     1.000000    1547.000000
# 50%      500.50000   763.000000   765.500000     2.000000    2829.500000
# 75%      750.25000  1404.000000  1417.250000     4.000000    4584.750000
# max    12356.00000  3000.000000  5670.000000   180.000000  249352.000000
#
#            yrbuilt     total_uses           cie           med           mips  \
# count  1000.000000    1000.000000   1000.000000   1000.000000    1000.000000
# mean   1806.671000    3671.537000    298.710000    128.593000    1977.363000
# std     468.030257   14035.781531   2003.860992   1124.511807    9495.755121
# ...

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
land_use.describe()
# Out:
#                   objectid              from_st                to_st  \
# count             1,000.00               982.00               982.00
# mean                511.86               949.50               957.96
# std                 473.00               809.77               823.27
# min                   1.00                 0.00                 0.00
# 25%                 250.75               291.00               294.25
# 50%                 500.50               763.00               765.50
# 75%                 750.25             1,404.00             1,417.25
# max              12,356.00             3,000.00             5,670.00
#
#                   resunits             bldgsqft              yrbuilt  \
# count             1,000.00             1,000.00             1,000.00
# mean                  4.47             6,910.70             1,806.67
# std                  13.65            21,511.28               468.03
# ...

# %%
land_use.loc[land_use.resunits>0].groupby('resunits').total_uses.describe()
# Out:
#                         count                 mean                  std  \
# resunits
# 1                      118.00               370.80               990.55
# 2                      205.00               497.04             1,289.71
# 3                      201.00               861.59             1,713.72
# 4                       76.00             1,171.88             2,442.64
# 5                       34.00               772.85             1,432.96
# 6                       73.00               738.82             1,369.21
# 7                       11.00               872.09             1,248.45
# 8                        7.00               555.29               958.44
# 9                       12.00               806.00             1,223.88
# 10                       7.00             2,042.14             1,538.80
# 11                       4.00             1,072.25             1,339.33
# 12                      11.00             3,232.64             4,573.99
# ...

# %%
# download MOHCD Affordable Rental Portfolio
mohcd_url = "https://data.sfgov.org/resource/9rdx-httc.csv"
mohcd = pd.read_csv(mohcd_url)
mohcd.head()
# Out:
#   project_id                                       project_name street_number  \
# 0   1969-001  Martin Luther King-Marcus Garvey Square Cooper...          1680
# 1   1970-001                       Ridgeview Terrace Apartments           140
# 2   1972-001                                  Sutter Apartments          1480
# 3   1973-001                                 Nihonmachi Terrace          1615
# 4   1980-001                               Consorcia Apartments          1204
#
#   street_name street_type project_address           neighborhood  \
# 0        Eddy          St           94115       Western Addition
# 1    Cashmere          St           94124  Bayview Hunters Point
# 2      Sutter          St           94109       Western Addition
# 3      Sutter          St           94109              Japantown
# 4       Mason          St           94133              Chinatown
#
#    supervisor_district                                    project_sponsor  \
# ...

# %%
# download Zoning District Data
zoning_url = "https://data.sfgov.org/resource/yamn-gsa8.csv"
zoning = pd.read_csv(zoning_url)
zoning.head()
# Out:
#                                             the_geom  objectid zoning_sim  \
# 0  MULTIPOLYGON (((-122.430526834 37.722469476, -...     19300       RH-2
# 1  MULTIPOLYGON (((-122.438509606 37.721232545, -...     20263          P
# 2  MULTIPOLYGON (((-122.435249516 37.763363106, -...     19971       RM-1
# 3  MULTIPOLYGON (((-122.414154717 37.775113424, -...     20472     RED-MX
# 4  MULTIPOLYGON (((-122.419818481 37.754952718, -...     20205          P
#
#                       districtname  \
# 0   RESIDENTIAL- HOUSE, TWO FAMILY
# 1                           PUBLIC
# 2  RESIDENTIAL- MIXED, LOW DENSITY
# 3        RESIDENTIAL ENCLAVE-MIXED
# 4                           PUBLIC
#
#                                                  url          gen  zoning  \
# 0  https://codelibrary.amlegal.com/codes/san_fran...  Residential    RH-2
# 1  https://codelibrary.amlegal.com/codes/san_fran...       Public       P
# 2  https://codelibrary.amlegal.com/codes/san_fran...  Residential    RM-1
# ...
